# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://en.wikipedia.org/wiki/List_of_companies_of_Bangladesh'

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of companies of Bangladesh - Wikipedia</title>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of companies of Bangladesh - Wikipedia
#   </title>
#   <script>
# ...

# %% [markdown]
# # FIND (first Instance)

# %%
soup.find('div')
# Out:
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark" role="navigation">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label"><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
# <span class="vector-dropdown-label-text">Main menu</span>
# </label>
# <div class="vector-dropdown-content">
# ...

# %% [markdown]
# # FIND_ALL (All instances)

# %%
soup.find("table")
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr>
# <td><a href="/wiki/A_K_Khan_%26_Company" title="A K Khan &amp; Company">A K Khan &amp; Company</a>
# </td>
# <td>Conglomerates
# </td>
# <td>-
# </td>
# <td><a href="/wiki/Chittagong" title="Chittagong">Chittagong</a>
# </td>
# <td>1945
# </td>
# ...

# %%
table=soup.find("table")

# %%
soup.find('table',class_="wikitable sortable")
# Out:
# <table class="wikitable sortable">
# <caption>Notable companies <br/>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9f9f9; color:#f9f9f9;">    </span> Active</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#f9e6ff; color:#f9e6ff;">    </span> State-owned</span>
# <span style="margin:0px; font-size:90%;"><span style="border:1px solid #000; background-color:#dddddd; color:#dddddd;">    </span> Defunct</span>
# </caption>
# <tbody><tr>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Sector
# </th>
# <th>Headquarters
# </th>
# <th>Founded
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr>
# <td><a href="/wiki/A_K_Khan_%26_Company" title="A K Khan &amp; Company">A K Khan &amp; Company</a>
# </td>
# <td>Conglomerates
# </td>
# <td>-
# </td>
# <td><a href="/wiki/Chittagong" title="Chittagong">Chittagong</a>
# </td>
# <td>1945
# </td>
# ...

# %%
cName=table.find_all('th')
cName
# Out:
# [<th>Name
#  </th>,
#  <th>Industry
#  </th>,
#  <th>Sector
#  </th>,
#  <th>Headquarters
#  </th>,
#  <th>Founded
#  </th>,
#  <th class="unsortable">Notes
#  </th>]

# %%
CompanyName_table_title= [x.text.strip() for x in cName]

print(CompanyName_table_title)
# Out:
# ['Name', 'Industry', 'Sector', 'Headquarters', 'Founded', 'Notes']

# %%
table.find_all('td')
# Out:
# [<td><a href="/wiki/A_K_Khan_%26_Company" title="A K Khan &amp; Company">A K Khan &amp; Company</a>
#  </td>,
#  <td>Conglomerates
#  </td>,
#  <td>-
#  </td>,
#  <td><a href="/wiki/Chittagong" title="Chittagong">Chittagong</a>
#  </td>,
#  <td>1945
#  </td>,
#  <td>Textiles, logistics, water, financial services, telecoms, agriculture
#  </td>,
#  <td><a href="/wiki/Aarong" title="Aarong">Aarong</a>
#  </td>,
#  <td>Consumer goods
#  </td>,
#  <td>Personal &amp; household goods
#  </td>,
#  <td><a href="/wiki/Dhaka" title="Dhaka">Dhaka</a>
#  </td>,
#  <td>1978
#  </td>,
#  <td>General retail
#  </td>,
#  <td><a href="/wiki/Abul_Khair_Group" title="Abul Khair Group">Abul Khair Group</a>
#  </td>,
#  <td>Conglomerates
#  </td>,
#  <td>-
#  </td>,
#  <td><a class="mw-redirect" href="/wiki/Chattogram" title="Chattogram">Chattogram</a>
#  </td>,
#  <td>1953
#  </td>,
#  <td>Steel, cement, tobacco, food &amp; beverage, consumer product, automobile
#  </td>,
# ...

# %%
column_data=table.find_all('tr')
column_data
# Out:
# [<tr>
#  <th>Name
#  </th>
#  <th>Industry
#  </th>
#  <th>Sector
#  </th>
#  <th>Headquarters
#  </th>
#  <th>Founded
#  </th>
#  <th class="unsortable">Notes
#  </th></tr>,
#  <tr>
#  <td><a href="/wiki/A_K_Khan_%26_Company" title="A K Khan &amp; Company">A K Khan &amp; Company</a>
#  </td>
#  <td>Conglomerates
#  </td>
#  <td>-
#  </td>
#  <td><a href="/wiki/Chittagong" title="Chittagong">Chittagong</a>
#  </td>
#  <td>1945
#  </td>
#  <td>Textiles, logistics, water, financial services, telecoms, agriculture
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Aarong" title="Aarong">Aarong</a>
#  </td>
#  <td>Consumer goods
#  </td>
#  <td>Personal &amp; household goods
#  </td>
#  <td><a href="/wiki/Dhaka" title="Dhaka">Dhaka</a>
#  </td>
#  <td>1978
#  </td>
#  <td>General retail
#  </td></tr>,
#  <tr>
#  <td><a href="/wiki/Abul_Khair_Group" title="Abul Khair Group">Abul Khair Group</a>
#  </td>
#  <td>Conglomerates
#  </td>
#  <td>-
#  </td>
# ...

# %%
for row in column_data[1:]:

    row_data=row.find_all('td')
    individual_row_data= [ i.text.strip() for i in row_data]

    length_dataframe=len(df)
    df.loc[length_dataframe]=individual_row_data

    print(individual_row_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       3 row_data=row.find_all('td')
#       4 individual_row_data= [ i.text.strip() for i in row_data]
# ----> 6 length_dataframe=len(df)
#       7 df.loc[length_dataframe]=individual_row_data
#       9 print(individual_row_data)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Export Pandas dataframe

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=CompanyName_table_title)
df
# Out:
# Empty DataFrame
# Columns: [Name, Industry, Sector, Headquarters, Founded, Notes]
# Index: []

# %%
df[50:75]
# Out:
#                                           Name            Industry  \
# 50                          Ekushey Television   Consumer services
# 51                          Eskayef Bangladesh         Health care
# 52                                   EXIM Bank          Financials
# 53                        FMC Dockyard Limited         Industrials
# 54                              General Pharma         Health care
# 55             Globe Janakantha Shilpa Paribar       Conglomerates
# 56                                GMG Airlines   Consumer services
# 57                                Grameen Bank          Financials
# 58                                Grameenphone  Telecommunications
# 59                                 Habib Group       Conglomerates
# 60                               Ha-meem Group      Consumer goods
# 61                                   HRC Group       Conglomerates
# 62               IDLC Asset Management Limited          Financials
# ...

# %%
df.to_csv(r'C:\DEV\Python\web_scrapping\Deshi_Companies.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df.to_csv(r'C:\DEV\Python\web_scrapping\Deshi_Companies.csv',index=False)
#
# File c:\Users\User\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\User\anaconda3\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
# ...
